# %% [markdown]
# # Testing Luenberger Observer

# %%
from tclab import TCLab, Historian, Plotter, clock, setup
TCLab = setup(connected=False)

import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
% matplotlib inline

A = np.matrix([[-0.01764863,0.00804479],[ 0.03706835,-0.03706835]])
B = np.matrix([[4/7],[0]])
C = np.matrix([[0,1]])

L = np.matrix([[1],[1]])



tfinal = 20

x_est = np.matrix([[20],[20]])

with TCLab() as lab:
    h = Historian([('T1', lambda: lab.T1),('T_obs', lambda: T_obs),('Q1', lab.Q1)])
    p = Plotter(h,tfinal)
    
    for t in clock(tfinal):
        
        error = lab.T1 - np.matmul(C,x_est)
        
        dx = np.matmul(A,x_est) #+ B*lab.Q1 + L*error
        x_est = x_est + dx
        
        T_obs = np.matmul(C,x_est)[0]        
        
        if t < 50:
            power = 80
        elif t < 100:
            power = 20
        elif t < 200:
            power = 50
        elif t < 250:
            power = 90
        else:
            power = 10
        
        lab.U1 = power       
        
        p.update(t)

#df = pd.DataFrame.from_records(h.log, columns=h.columns, index='Time')
#df.to_csv(e)
# Out:
# TCLab Model disconnected successfully.
# RuntimeErrorTraceback (most recent call last)
# <ipython-input-7-360ac90baf18> in <module>()
#      23     p = Plotter(h,tfinal)
#      24
# ---> 25     for t in clock(tfinal):
#      26
#      27         error = lab.T1 - np.matmul(C,x_est)
#
# C:\Users\David\Anaconda3\lib\site-packages\tclab\labtime.py in clock(period, step, tol, adaptive)
#      92         else:
#      93             if elapsed > step + tol:
# ---> 94                 raise RuntimeError('Labtime clock lost synchronization with real time.')
#      95         labtime.sleep(step - (labtime.time() - start) % step)
#      96         now = labtime.time() - start
#
# RuntimeError: Labtime clock lost synchronization with real time.
